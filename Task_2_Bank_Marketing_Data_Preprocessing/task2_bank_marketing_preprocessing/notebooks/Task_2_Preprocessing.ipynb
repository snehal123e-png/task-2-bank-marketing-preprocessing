# %% [markdown]
# # Task 2 — Bank Marketing Data Collection & Preprocessing
#
# This notebook runs the reproducible preprocessing pipeline.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))

# %%
# If the dataset is not downloaded, run download_and_run.py from the project root.
# Then inspect the processed outputs.
import pandas as pd
processed = ROOT / 'data' / 'processed'
summary = pd.read_csv(processed / 'preprocessing_summary.csv')
summary

# %%
df = pd.read_csv(processed / 'bank_marketing_cleaned.csv')
print('Shape:', df.shape)
df.head()

# %%
outliers = pd.read_csv(processed / 'outlier_report.csv')
outliers

# %% [markdown]
# ## Conclusion
#
# The pipeline performs collection, quality checks, duplicate removal, explicit treatment of `unknown` categories, numeric type conversion, IQR-based outlier treatment, feature engineering, target encoding, and one-hot encoding.
